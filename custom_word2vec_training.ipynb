# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('./data/'):
    print(file)
# Out:
# story1.txt
# story2.txt

# %%
f = open(r"C:\Users\DELL\full_stack_genai\Full-Stack-GenAI-Bootcamp-1.0\Class-06-07-11-12-Apr-Word2vec-with-practical\data\story1.txt",encoding='unicode_escape')

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\DELL\\full_stack_genai\\Full-Stack-GenAI-Bootcamp-1.0\\Class-06-07-11-12-Apr-Word2vec-with-practical\\data\\story1.txt' mode='r' encoding='unicode_escape'>

# %%
corpus =f.read()

# %%
corpus
# Out:
# 'Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills, rivers, and green fields. The town was peaceful, and life moved slowly there, but Arjunâ\x80\x99s mind was always full of questions. He was very curious about how things worked and always wanted to know the reason behind everything he saw. His parents often smiled at his curiosity and encouraged him to keep learning.\n\nEvery day after school, Arjun would sit with his books and explore different topics. Sometimes he read about nature, sometimes about mathematics, and sometimes about machines. He was especially fascinated by science and technology. He wanted to understand how machines think, how computers solve problems, and whether they could ever become as intelligent as humans.\n\nAt school, Arjun was known as the boy who asked many questions. He would ask his teachers how electricity moves through wires, how radios send sound over long distances, and how calculators can solve proble
# ...

# %%
sent_tokenize(corpus)
# Out:
# ['Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills, rivers, and green fields.',
#  'The town was peaceful, and life moved slowly there, but Arjunâ\x80\x99s mind was always full of questions.',
#  'He was very curious about how things worked and always wanted to know the reason behind everything he saw.',
#  'His parents often smiled at his curiosity and encouraged him to keep learning.',
#  'Every day after school, Arjun would sit with his books and explore different topics.',
#  'Sometimes he read about nature, sometimes about mathematics, and sometimes about machines.',
#  'He was especially fascinated by science and technology.',
#  'He wanted to understand how machines think, how computers solve problems, and whether they could ever become as intelligent as humans.',
#  'At school, Arjun was known as the boy who asked many questions.',
# ...

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
  print(simple_preprocess(i))
# Out:
# ['once', 'upon', 'time', 'there', 'was', 'young', 'boy', 'named', 'arjun', 'who', 'lived', 'in', 'small', 'town', 'surrounded', 'by', 'hills', 'rivers', 'and', 'green', 'fields']
# ['the', 'town', 'was', 'peaceful', 'and', 'life', 'moved', 'slowly', 'there', 'but', 'arjunâ', 'mind', 'was', 'always', 'full', 'of', 'questions']
# ['he', 'was', 'very', 'curious', 'about', 'how', 'things', 'worked', 'and', 'always', 'wanted', 'to', 'know', 'the', 'reason', 'behind', 'everything', 'he', 'saw']
# ['his', 'parents', 'often', 'smiled', 'at', 'his', 'curiosity', 'and', 'encouraged', 'him', 'to', 'keep', 'learning']
# ['every', 'day', 'after', 'school', 'arjun', 'would', 'sit', 'with', 'his', 'books', 'and', 'explore', 'different', 'topics']
# ['sometimes', 'he', 'read', 'about', 'nature', 'sometimes', 'about', 'mathematics', 'and', 'sometimes', 'about', 'machines']
# ['he', 'was', 'especially', 'fascinated', 'by', 'science', 'and', 'technology']
# ...

# %%
folder_path = r"C:\Users\DELL\full_stack_genai\Full-Stack-GenAI-Bootcamp-1.0\Class-06-07-11-12-Apr-Word2vec-with-practical\data"
story = []
for filename in os.listdir(folder_path):
  file_path=os.path.join(folder_path,filename)
  with open(file_path,encoding='unicode_escape') as f:
    corpus=f.read()
  raw_sent=sent_tokenize(corpus)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['once',
#   'upon',
#   'time',
#   'there',
#   'was',
#   'young',
#   'boy',
#   'named',
#   'arjun',
#   'who',
#   'lived',
#   'in',
#   'small',
#   'town',
#   'surrounded',
#   'by',
#   'hills',
#   'rivers',
#   'and',
#   'green',
#   'fields'],
#  ['the',
#   'town',
#   'was',
#   'peaceful',
#   'and',
#   'life',
#   'moved',
#   'slowly',
#   'there',
#   'but',
#   'arjunâ',
#   'mind',
#   'was',
#   'always',
#   'full',
#   'of',
#   'questions'],
#  ['he',
#   'was',
#   'very',
#   'curious',
#   'about',
#   'how',
#   'things',
#   'worked',
#   'and',
#   'always',
#   'wanted',
#   'to',
#   'know',
#   'the',
#   'reason',
#   'behind',
#   'everything',
#   'he',
#   'saw'],
#  ['his',
#   'parents',
#   'often',
#   'smiled',
#   'at',
#   'his',
#   'curiosity',
#   'and',
#   'encouraged',
#   'him',
#   'to',
#   'keep',
#   'learning'],
#  ['every',
#   'day',
#   'after',
#   'school',
#   'arjun',
#   'would',
#   'sit',
#   'with',
#   'his',
# ...

# %%
len(story)
# Out:
# 104

# %%
story[0]
# Out:
# ['once',
#  'upon',
#  'time',
#  'there',
#  'was',
#  'young',
#  'boy',
#  'named',
#  'arjun',
#  'who',
#  'lived',
#  'in',
#  'small',
#  'town',
#  'surrounded',
#  'by',
#  'hills',
#  'rivers',
#  'and',
#  'green',
#  'fields']

# %%
story[1]
# Out:
# ['the',
#  'town',
#  'was',
#  'peaceful',
#  'and',
#  'life',
#  'moved',
#  'slowly',
#  'there',
#  'but',
#  'arjunâ',
#  'mind',
#  'was',
#  'always',
#  'full',
#  'of',
#  'questions']

# %%
sunny->100
Divyansh->6
Rahul->3

# %%
# Word2Vec(..., sg=0)  # CBOW #by default
# Word2Vec(..., sg=1)  # Skip-gram

# %%
# custom_model =gensim.models.Word2Vec(
#     window=10,
#     min_count=5,
#     vector_size=150
    
# )

## these all the value are the hyperparameter

# %%
custom_model =gensim.models.Word2Vec(
    window=10,
    min_count=1,
    vector_size=150
    
)

# %%
custom_model.build_vocab(story)

# %%
len(custom_model.wv.index_to_key)
# Out:
# 522

# %%
custom_model.corpus_count
# Out:
# 104

# %%
custom_model.corpus_count
# Out:
# 104

# %%
custom_model.train(story, total_examples=custom_model.corpus_count, epochs=10)
# Out:
# (10367, 14130)

# %%
custom_model.wv["arjun"]
# Out:
# array([-5.1301271e-03, -1.7417829e-03,  6.7157885e-03, -5.5188322e-03,
#        -3.0091270e-03,  4.9821683e-03, -6.0459236e-03,  9.0341391e-03,
#         3.4136185e-04,  7.6591456e-03,  7.1722935e-03, -3.2915436e-03,
#        -2.4958781e-03, -4.0281941e-03, -6.6011008e-03,  4.0388610e-03,
#         6.9679450e-03,  4.8687640e-03,  6.2897978e-03, -1.1978529e-03,
#        -1.3232932e-03, -4.0698694e-03,  5.0345254e-03,  3.9983662e-03,
# ...

# %%
custom_model.wv.most_similar("arjun")
# Out:
# [('and', 0.6239988207817078),
#  ('he', 0.5767260789871216),
#  ('of', 0.5334029793739319),
#  ('farmers', 0.5163472890853882),
#  ('that', 0.5094478726387024),
#  ('could', 0.5000675320625305),
#  ('knowledge', 0.49590426683425903),
#  ('can', 0.48948749899864197),
#  ('were', 0.48360222578048706),
#  ('the', 0.48218345642089844)]

# %%
custom_model.wv.most_similar("ai")
# Out:
# [('of', 0.39265087246894836),
#  ('can', 0.343495637178421),
#  ('very', 0.33828985691070557),
#  ('days', 0.3203057646751404),
#  ('crops', 0.28484970331192017),
#  ('many', 0.2838762700557709),
#  ('and', 0.27734920382499695),
#  ('also', 0.2725212574005127),
#  ('new', 0.2660059928894043),
#  ('in', 0.26285532116889954)]

# %%
custom_model.wv.most_similar("engineer")
# Out:
# [('mind', 0.3324287533760071),
#  ('were', 0.3198873698711395),
#  ('him', 0.3156108856201172),
#  ('and', 0.2977117896080017),
#  ('many', 0.27336248755455017),
#  ('system', 0.26936131715774536),
#  ('who', 0.26669320464134216),
#  ('slowly', 0.24670261144638062),
#  ('wanted', 0.24368886649608612),
#  ('follow', 0.24332013726234436)]

# %%
custom_model.wv.most_similar("data")
# Out:
# [('and', 0.4130496680736542),
#  ('he', 0.3963492810726166),
#  ('how', 0.3945333659648895),
#  ('that', 0.39381590485572815),
#  ('of', 0.3818056583404541),
#  ('were', 0.38180094957351685),
#  ('to', 0.3809477686882019),
#  ('knowledge', 0.38059017062187195),
#  ('arjun', 0.36848747730255127),
#  ('building', 0.35558152198791504)]

# %%
custom_model.wv.doesnt_match(["arjun", "engineer", "programming", "farmers"])
# Out:
# 'programming'

# %%
custom_model.wv.doesnt_match(["data", "model", "system", "river"])
# Out:
# 'river'

# %%
custom_model.wv.doesnt_match(["weather", "crops", "farmers", "technology"])
# Out:
# 'crops'

# %%
google-news-million of Artical
neural and llm -> data hungry

# %%
custom_model.wv.similarity("ai", "technology")
# Out:
# 0.1189804

# %%
custom_model.wv.similarity("arjun", "engineer")
# Out:
# 0.1575414

# %% [markdown]
# ## Assignment for this week
#
# ## add more data
# ## train for more epoch
# ## and check the accuracy of model
# ## check the embedding dimesion also
#
# ## inshort play with all the parameter

# %%
SOTA/ Transformer

# %%
print(custom_model.wv.doesnt_match(["farmer", "crop", "soil", "ai"]))
print(custom_model.wv.doesnt_match(["data", "model", "algorithm", "river"]))
print(custom_model.wv.doesnt_match(["village", "river", "hill", "programming"]))
print(custom_model.wv.doesnt_match(["teacher", "student", "school", "weather"]))
# Out:
# ai
# river
# river
# teacher
